# %% [markdown]
# <img src="img/viu_logo.png" width="200">
#
# ## 01MIAR - Estructuras de datos, +Pandas
#
# ![logo](img/python_logo.png)
#
# *Ivan Fuertes / Andrés Pérez*

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Operaciones en pandas

# %% [markdown]
# #### Búsqueda

# %%
rand_matrix = np.random.randint(6,size=(2,3))
frame = pd.DataFrame(rand_matrix , columns=list('ABC'))
display(frame)
# Out:
#    A  B  C
# 0  4  4  5
# 1  1  4  3

# %%
# buscando columnas (DataFrame como dic, busca en claves)
'A' in frame
# Out:
# True

# %%
# buscando valores
display(frame.isin([3,2])) # --> mask de respuesta (valores que son 3 o 2)
# Out:
#        A      B      C
# 0  False  False  False
# 1  False  False   True

# %%
# Contar el número de ocurrencias
print(frame.isin([5]).values.sum())
display(frame.isin([5])) #devuelve una mask con valores true si el elemento es 5
type(frame.isin([5]).values) # pandas es una capa alrededor de numpy
# Out:
# 1
#        A      B      C
# 0  False  False   True
# 1  False  False  False
# numpy.ndarray

# %%
# Cuántos valores son >= 4
mask = frame >= 4
print(mask.values.sum())
display(mask)
# Out:
# 4
#        A     B      C
# 0   True  True   True
# 1  False  True  False

# %% [markdown]
# #### Ordenación

# %%
from random import shuffle

rand_matrix = np.random.randint(20,size=(5,4))

indices = list(range(5))
shuffle(indices) # mezcla indices

frame = pd.DataFrame(rand_matrix , columns=list('DACB'), index=indices)
display(frame)
# Out:
#    D   A   C   B
# 3  9   8  15  13
# 0  7  12   4   0
# 1  4   4   5  16
# 4  1  14   0  16
# 2  6   2   8  16

# %%
# ordenar por índice
display(frame.sort_index(ascending=True))
display(frame)
# Out:
#    D   A   C   B
# 0  7  12   4   0
# 1  4   4   5  16
# 2  6   2   8  16
# 3  9   8  15  13
# 4  1  14   0  16
#    D   A   C   B
# 3  9   8  15  13
# 0  7  12   4   0
# 1  4   4   5  16
# 4  1  14   0  16
# 2  6   2   8  16

# %%
#ordenar por columna
display(frame.sort_index(axis=1, ascending=True))
# Out:
#     A   B   C  D
# 3   8  13  15  9
# 0  12   0   4  7
# 1   4  16   5  4
# 4  14  16   0  1
# 2   2  16   8  6

# %%
# ordenar filas por valor en columna
display(frame.sort_values(by='A', ascending=True))
# Out:
#    D   A   C   B
# 2  6   2   8  16
# 1  4   4   5  16
# 3  9   8  15  13
# 0  7  12   4   0
# 4  1  14   0  16

# %%
# ordenar columnas por valor en fila
display(frame.sort_values(by=1, axis=1, ascending=True))
# Out:
#    D   A   C   B
# 3  9   8  15  13
# 0  7  12   4   0
# 1  4   4   5  16
# 4  1  14   0  16
# 2  6   2   8  16

# %%
# ordenar por valor en columna y guardar cambios
frame.sort_values(by='A', ascending=False, inplace=True)
display(frame)
# Out:
#    D   A   C   B
# 4  1  14   0  16
# 0  7  12   4   0
# 3  9   8  15  13
# 1  4   4   5  16
# 2  6   2   8  16

# %% [markdown]
# #### Ranking
# - Construir un ranking de valores

# %%
display(frame)
# Out:
#    D   A   C   B
# 4  1  14   0  16
# 0  7  12   4   0
# 3  9   8  15  13
# 1  4   4   5  16
# 2  6   2   8  16

# %%
display(frame.rank(method='average'))
# Out:
#      D    A    C    B
# 4  1.0  5.0  1.0  4.0
# 0  4.0  4.0  2.0  1.0
# 3  5.0  3.0  5.0  2.0
# 1  2.0  2.0  3.0  4.0
# 2  3.0  1.0  4.0  4.0

# %%
# Imprimir, uno a uno, los valores de la columna 'C' de mayor a menor
for x in frame.sort_values(by='C', ascending=False)['C'].values:
    print(x)
# Out:
# 15
# 8
# 5
# 4
# 0

# %% [markdown]
# # Operaciones

# %% [markdown]
# Operaciones matemáticas entre objetos

# %%
matrixA = np.random.randint(100,size=(4,4))
matrixB = np.random.randint(100,size=(4,4))
frameA = pd.DataFrame(matrixA)
frameB = pd.DataFrame(matrixB)
display(frameA)
display(frameB)
# Out:
#     0   1   2   3
# 0  97   7  65  74
# 1  27  78   8   6
# 2   5  56  99  98
# 3  86  63   0  71
#     0   1   2   3
# 0  63   8  32  19
# 1  73  79  88  30
# 2  45  62  84  61
# 3  29  21  21  90

# %%
# a través de métodos u operadores
display(frameA + frameB == frameA.add(frameB))
display(frameA + frameB)
# Out:
#       0     1     2     3
# 0  True  True  True  True
# 1  True  True  True  True
# 2  True  True  True  True
# 3  True  True  True  True
#      0    1    2    3
# 0  160   15   97   93
# 1  100  157   96   36
# 2   50  118  183  159
# 3  115   84   21  161

# %%
display(frameB - frameA == frameB.sub(frameA))
display(frameB - frameA)
# Out:
#       0     1     2     3
# 0  True  True  True  True
# 1  True  True  True  True
# 2  True  True  True  True
# 3  True  True  True  True
#     0   1   2   3
# 0 -34   1 -33 -55
# 1  46   1  80  24
# 2  40   6 -15 -37
# 3 -57 -42  21  19

# %%
# si los frames no son iguales, valor por defecto NaN
frameC = pd.DataFrame(np.random.randint(100,size=(3,3)))
display(frameA)
display(frameC)
display(frameA + frameC)
# Out:
#     0   1   2   3
# 0  97   7  65  74
# 1  27  78   8   6
# 2   5  56  99  98
# 3  86  63   0  71
#     0   1   2
# 0  49  37   9
# 1   8  50  78
# 2  48   7  97
#        0      1      2   3
# 0  146.0   44.0   74.0 NaN
# 1   35.0  128.0   86.0 NaN
# 2   53.0   63.0  196.0 NaN
# 3    NaN    NaN    NaN NaN

# %%
# se puede especificar el valor por defecto con el argumento fill_value
display(frameA.add(frameC, fill_value=0))
# Out:
#        0      1      2     3
# 0  146.0   44.0   74.0  74.0
# 1   35.0  128.0   86.0   6.0
# 2   53.0   63.0  196.0  98.0
# 3   86.0   63.0    0.0  71.0

# %% [markdown]
# Operadores aritméticos solo válidos en elementos aceptables

# %%
frameD = pd.DataFrame({0: ['a','b'],1:['d','f']})
display(frameD)
frameA - frameD
# Out:
#    0  1
# 0  a  d
# 1  b  f
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\ops\array_ops.py:220, in _na_arithmetic_op(left, right, op, is_cmp)
#     219 try:
# --> 220     result = func(left, right)
#     221 except TypeError:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\computation\expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\computation\expressions.py:73, in _evaluate_standard(op, op_str, a, b)
#      72     _store_test_result(False)
# ---> 73 return op(a, b)
#
# TypeError: unsupported operand type(s) for -: 'int' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 3
#       1 frameD = pd.DataFrame({0: ['a','b'],1:['d','f']})
#       2 display(frameD)
# ----> 3 frameA - frameD
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\arraylike.py:194, in OpsMixin.__sub__(self, other)
#     192 @unpack_zerodim_and_defer("__sub__")
#     193 def __sub__(self, other):
# --> 194     return self._arith_method(other, operator.sub)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:7636, in DataFrame._arith_method(self, other, op)
#    7634 def _arith_method(self, other, op):
#    7635     if self._should_reindex_frame_op(other, op, 1, None, None):
# -> 7636         return self._arith_method_with_reindex(other, op)
#    7638     axis: Literal[1] = 1  # only relevant for Series other case
#    7639     other = ops.maybe_prepare_scalar_for_op(other, (self.shape[axis],))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:7768, in DataFrame._arith_method_with_reindex(self, right, op)
#    7766 new_left = left.iloc[:, lcols]
#    7767 new_right = right.iloc[:, rcols]
# -> 7768 result = op(new_left, new_right)
#    7770 # Do the join on the columns instead of using left._align_for_op
#    7771 #  to avoid constructing two potentially large/sparse DataFrames
#    7772 join_columns, _, _ = left.columns.join(
#    7773     right.columns, how="outer", level=None, return_indexers=True
#    7774 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\arraylike.py:194, in OpsMixin.__sub__(self, other)
#     192 @unpack_zerodim_and_defer("__sub__")
#     193 def __sub__(self, other):
# --> 194     return self._arith_method(other, operator.sub)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:7644, in DataFrame._arith_method(self, other, op)
#    7641 self, other = self._align_for_op(other, axis, flex=True, level=None)
#    7643 with np.errstate(all="ignore"):
# -> 7644     new_data = self._dispatch_frame_op(other, op, axis=axis)
#    7645 return self._construct_result(new_data)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:7687, in DataFrame._dispatch_frame_op(self, right, func, axis)
#    7681     assert self.columns.equals(right.columns)
#    7682     # TODO: The previous assertion `assert right._indexed_same(self)`
#    7683     #  fails in cases with empty columns reached via
#    7684     #  _frame_arith_method_with_reindex
#    7685
#    7686     # TODO operate_blockwise expects a manager of the same type
# -> 7687     bm = self._mgr.operate_blockwise(
#    7688         # error: Argument 1 to "operate_blockwise" of "ArrayManager" has
#    7689         # incompatible type "Union[ArrayManager, BlockManager]"; expected
#    7690         # "ArrayManager"
#    7691         # error: Argument 1 to "operate_blockwise" of "BlockManager" has
#    7692         # incompatible type "Union[ArrayManager, BlockManager]"; expected
#    7693         # "BlockManager"
#    7694         right._mgr,  # type: ignore[arg-type]
#    7695         array_op,
#    7696     )
#    7697     return self._constructor_from_mgr(bm, axes=bm.axes)
#    7699 elif isinstance(right, Series) and axis == 1:
#    7700     # axis=1 means we want to operate row-by-row
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\internals\managers.py:1470, in BlockManager.operate_blockwise(self, other, array_op)
#    1466 def operate_blockwise(self, other: BlockManager, array_op) -> BlockManager:
#    1467     """
#    1468     Apply array_op blockwise with another (aligned) BlockManager.
#    1469     """
# -> 1470     return operate_blockwise(self, other, array_op)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\internals\ops.py:65, in operate_blockwise(left, right, array_op)
#      63 res_blks: list[Block] = []
#      64 for lvals, rvals, locs, left_ea, right_ea, rblk in _iter_block_pairs(left, right):
# ---> 65     res_values = array_op(lvals, rvals)
#      66     if (
#      67         left_ea
#      68         and not right_ea
#      69         and hasattr(res_values, "reshape")
#      70         and not is_1d_only_ea_dtype(res_values.dtype)
#      71     ):
#      72         res_values = res_values.reshape(1, -1)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\ops\array_ops.py:285, in arithmetic_op(left, right, op)
#     281     _bool_arith_check(op, left, right)  # type: ignore[arg-type]
#     283     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     284     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 285     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     287 return res_values
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\ops\array_ops.py:229, in _na_arithmetic_op(left, right, op, is_cmp)
#     221 except TypeError:
#     222     if not is_cmp and (
#     223         left.dtype == object or getattr(right, "dtype", None) == object
#     224     ):
#    (...)
#     227         # Don't do this for comparisons, as that will handle complex numbers
#     228         #  incorrectly, see GH#32047
# --> 229         result = _masked_arith_op(left, right, op)
#     230     else:
#     231         raise
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\ops\array_ops.py:165, in _masked_arith_op(x, y, op)
#     163     # See GH#5284, GH#5035, GH#19448 for historical reference
#     164     if mask.any():
# --> 165         result[mask] = op(xrav[mask], yrav[mask])
#     167 else:
#     168     if not is_scalar(y):
#
# TypeError: unsupported operand type(s) for -: 'int' and 'str'

# %% [markdown]
# Operaciones entre Series y DataFrames

# %%
rand_matrix = np.random.randint(10, size=(3, 4))
df = pd.DataFrame(rand_matrix , columns=list('ABCD'))
display(df)

display(df.iloc[0])
# uso común, averiguar la diferencia entre una fila y el resto
display(df - df.iloc[0])
display(df.sub(df.iloc[0], axis=1))
# Por columnas cómo se restaría
display(df.sub(df['A'], axis=0))
# Out:
#    A  B  C  D
# 0  7  6  4  7
# 1  7  5  0  3
# 2  9  4  4  4
# A    7
# B    6
# C    4
# D    7
# Name: 0, dtype: int32
#    A  B  C  D
# 0  0  0  0  0
# 1  0 -1 -4 -4
# 2  2 -2  0 -3
#    A  B  C  D
# 0  0  0  0  0
# 1  0 -1 -4 -4
# 2  2 -2  0 -3
#    A  B  C  D
# 0  0 -1 -3  0
# 1  0 -2 -7 -4
# 2  0 -5 -5 -5

# %% [markdown]
# pandas se basa en NumPy, np operadores binarios y unarios son aceptables
#
# | Tipo | Operación | Descripción |
# |:---------|:-----|:-----|
# | Unario | *abs* | Valor absoluto de cada elemento |
# | | *sqrt* | Raíz cuadrada de cada elemento |
# | | *exp* | e^x, siendo x cad elemento |
# | | *log, log10, log2* | Logaritmos en distintas bases de cada elemento |
# | | *sign* | Retorna el signo de cada elemento (-1 para negativo, 0 o 1 para positivo) |
# | | *ceil* | Redondea cada elemento por arriba |
# | | *floor* | Redondea cada elemento por abajo |
# | | *isnan* | Retorna si cada elemento es Nan |
# | | *cos, sin, tan* | Operaciones trigonométricas en cada elemento |
# | | *arccos, arcsin, arctan* | Inversas de operaciones trigonométricas en cada elemento |
# | Binario | *add* | Suma de dos arrays |
# | | *substract* | Resta de dos arrays |
# | | *multiply* | Multiplicación de dos arrays |
# | | *divide* | División de dos arrays |
# | | *maximum, minimum* | Retorna el valor máximo/mínimo de cada pareja de elementos |
# | | *equal, not_equal* | Retorna la comparación (igual o no igual) de cada pareja de elementos |
# | | *greater, greater_equal, less, less_equal* | Retorna la comparación (>, >=, <, <= respectivamente) de cada pareja de elementos |

# %% [markdown]
# Aplicación de funciones a medida con lambda

# %%
rand_matrix = np.random.randint(10, size=(3, 4))
frame = pd.DataFrame(rand_matrix , columns=list('ABCD'))
display(frame)
print(frame.apply(lambda x : x.max() - x.min())) # diferencia por columna
# Out:
#    A  B  C  D
# 0  4  4  0  8
# 1  8  5  0  0
# 2  1  1  0  8
# A    7
# B    4
# C    0
# D    8
# dtype: int32

# %%
# diferencia entre min y max por fila (no columna)
rand_matrix = np.random.randint(10, size=(3, 4))
frame = pd.DataFrame(rand_matrix , columns=list('ABCD'))
display(frame)
print(frame.apply(lambda x : x.max() - x.min(), axis = 1)) # diferencia por fila
# Out:
#    A  B  C  D
# 0  3  4  7  3
# 1  3  2  7  0
# 2  9  5  4  3
# 0    4
# 1    7
# 2    6
# dtype: int32

# %% [markdown]
# # Estadística descriptiva
# - Análisis preliminar de los datos
# - Para Series y DataFrame
#
# | Operación | Descripción |
# |:----------|:------------|
# | count | Número de valores no NaN |
# | describe | Conjunto de estadísticas sumarias|
# | min, max | Valores mínimo y máximo |
# | argmin, argmax | Índices posicionales del valor mínimo y máximo |
# | idxmin, idxmax | Índices semánticos del valor mínimo y máximo |
# | sum | Suma de los elementos |
# | mean | Media de los elementos |
# | median | Mediana de los elementos |
# | mad | Desviación absoluta media del valor medio |
# | var | Varianza de los elementos |
# | std | Desviación estándar de los elementos |
# | cumsum | Suma acumulada de los elementos |
# | diff | Diferencia aritmética de los elementos |

# %%
diccionario = { "nombre" : ["Marisa","Laura","Manuel", "Carlos"], "edad" : [34,34,11, 30], 
               "puntos" : [98,12,98,np.nan], "genero": ["F", "F", "M", "M"] }
frame = pd.DataFrame(diccionario)
display(frame)
display(frame.describe()) # datos generales de elementos
# Out:
#    nombre  edad  puntos genero
# 0  Marisa    34    98.0      F
# 1   Laura    34    12.0      F
# 2  Manuel    11    98.0      M
# 3  Carlos    30     NaN      M
#             edad     puntos
# count   4.000000   3.000000
# mean   27.250000  69.333333
# std    10.996211  49.652123
# min    11.000000  12.000000
# 25%    25.250000  55.000000
# 50%    32.000000  98.000000
# 75%    34.000000  98.000000
# max    34.000000  98.000000

# %%
print(type(frame['edad']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
# operadores básicos
# print(frame.sum())

display(frame)
print(frame.sum(axis=1, numeric_only=True))
# Out:
#    nombre  edad  puntos genero
# 0  Marisa    34    98.0      F
# 1   Laura    34    12.0      F
# 2  Manuel    11    98.0      M
# 3  Carlos    30     NaN      M
# 0    132.0
# 1     46.0
# 2    109.0
# 3     30.0
# dtype: float64

# %%
frame.mean(numeric_only=True)
# Out:
# edad      27.250000
# puntos    69.333333
# dtype: float64

# %%
frame.cumsum()
# Out:
#                     nombre  edad  puntos genero
# 0                   Marisa    34    98.0      F
# 1              MarisaLaura    68   110.0     FF
# 2        MarisaLauraManuel    79   208.0    FFM
# 3  MarisaLauraManuelCarlos   109     NaN   FFMM

# %%
frame.count()
# Out:
# nombre    4
# edad      4
# puntos    3
# genero    4
# dtype: int64

# %%
frame['edad'].std()
# Out:
# 10.996211468804457

# %%
frame['edad'].idxmax()
# Out:
# 0

# %%
frame['puntos'].idxmin()
# Out:
# 1

# %%
# frame con las filas con los valores maximos de una columna
print(frame['puntos'].max())
display(frame[frame['puntos'] == frame['puntos'].max()])
# Out:
# 98.0
#    nombre  edad  puntos genero
# 0  Marisa    34    98.0      F
# 2  Manuel    11    98.0      M

# %% [markdown]
# ## Agregaciones

# %%
display(frame)
df = frame.groupby('genero').count()
display(df)
# Out:
#    nombre  edad  puntos genero
# 0  Marisa    34    98.0      F
# 1   Laura    34    12.0      F
# 2  Manuel    11    98.0      M
# 3  Carlos    30     NaN      M
#         nombre  edad  puntos
# genero
# F            2     2       2
# M            2     2       1

# %%
display(frame.groupby('genero').mean(numeric_only=True))
# Out:
#         edad  puntos
# genero
# F       34.0    55.0
# M       20.5    98.0

# %%
display(frame.groupby('genero').max())
# Out:
#         nombre  edad  puntos
# genero
# F       Marisa    34    98.0
# M       Manuel    30    98.0

# %%
# funciones de agregación de varias columnas para obtener distintos estadísticos
display(frame.groupby('genero')[['edad', 'puntos']].aggregate(['min', 'mean', 'max']))
# Out:
#        edad           puntos
#         min  mean max    min  mean   max
# genero
# F        34  34.0  34   12.0  55.0  98.0
# M        11  20.5  30   98.0  98.0  98.0

# %%
# Filtrado de los datos en el que el conjunto no supera una media determinada 
def media(x):
    return x["edad"].mean() > 30

display(frame)
frame.groupby('genero').filter(media)
# Out:
#    nombre  edad  puntos genero
# 0  Marisa    34    98.0      F
# 1   Laura    34    12.0      F
# 2  Manuel    11    98.0      M
# 3  Carlos    30     NaN      M
#    nombre  edad  puntos genero
# 0  Marisa    34    98.0      F
# 1   Laura    34    12.0      F

# %% [markdown]
# ## Correlaciones

# %% [markdown]
# pandas incluye métodos para analizar correlaciones
# - Relación matemática entre dos variables (-1 negativamente relacionadas, 1 positivamente relacionadas, 0 sin relación)
# - obj.corr(obj2) --> medida de correlación entre los datos de ambos objetos
# - https://blogs.oracle.com/ai-and-datascience/post/introduction-to-correlation

# %% [markdown]
# ### Ejemplo Fuel efficiency
# - https://archive.ics.uci.edu/ml/datasets/Auto+MPG

# %%
import pandas as pd
path = 'http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data'

mpg_data = pd.read_csv(path, delim_whitespace=True, header=None,
            names = ['mpg', 'cilindros', 'desplazamiento','potencia',
            'peso', 'aceleracion', 'año', 'origen', 'nombre'],
            na_values='?')

# %%
display(mpg_data.sample(5))
# Out:
#       mpg  cilindros  desplazamiento  potencia    peso  aceleracion  año  \
# 161  16.0          6           250.0     105.0  3897.0         18.5   75
# 124  11.0          8           350.0     180.0  3664.0         11.0   73
# 314  26.4          4           140.0      88.0  2870.0         18.1   80
# 332  29.8          4            89.0      62.0  1845.0         15.3   80
# 36   19.0          6           250.0      88.0  3302.0         15.5   71
#
#      origen                     nombre
# 161       1  chevroelt chevelle malibu
# 124       1           oldsmobile omega
# 314       1              ford fairmont
# 332       2           vokswagen rabbit
# 36        1            ford torino 500

# %%
display(mpg_data.describe(include='all'))
# Out:
#                mpg   cilindros  desplazamiento    potencia         peso  \
# count   398.000000  398.000000      398.000000  392.000000   398.000000
# unique         NaN         NaN             NaN         NaN          NaN
# top            NaN         NaN             NaN         NaN          NaN
# freq           NaN         NaN             NaN         NaN          NaN
# mean     23.514573    5.454774      193.425879  104.469388  2970.424623
# std       7.815984    1.701004      104.269838   38.491160   846.841774
# min       9.000000    3.000000       68.000000   46.000000  1613.000000
# 25%      17.500000    4.000000      104.250000   75.000000  2223.750000
# 50%      23.000000    4.000000      148.500000   93.500000  2803.500000
# 75%      29.000000    8.000000      262.000000  126.000000  3608.000000
# max      46.600000    8.000000      455.000000  230.000000  5140.000000
#
#         aceleracion         año      origen      nombre
# count    398.000000  398.000000  398.000000         398
# unique          NaN         NaN         NaN         305
# top             NaN         NaN         NaN  ford pinto
# freq            NaN         NaN         NaN           6
# mean      15.568090   76.010050    1.572864         NaN
# std        2.757689    3.697627    0.802055         NaN
# min        8.000000   70.000000    1.000000         NaN
# 25%       13.825000   73.000000    1.000000         NaN
# 50%       15.500000   76.000000    1.000000         NaN
# 75%       17.175000   79.000000    2.000000         NaN
# max       24.800000   82.000000    3.000000         NaN

# %%
mpg_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   mpg             398 non-null    float64
#  1   cilindros       398 non-null    int64
#  2   desplazamiento  398 non-null    float64
#  3   potencia        392 non-null    float64
#  4   peso            398 non-null    float64
#  5   aceleracion     398 non-null    float64
#  6   año             398 non-null    int64
#  7   origen          398 non-null    int64
#  8   nombre          398 non-null    object
# dtypes: float64(5), int64(3), object(1)
# memory usage: 28.1+ KB

# %% [markdown]
# ### Correlaciones entre valores

# %%
mpg_data['mpg'].corr(mpg_data['peso']) # + mpg = - peso
# Out:
# -0.8317409332443354

# %%
mpg_data['peso'].corr(mpg_data['aceleracion']) # + peso = - aceleracion
# Out:
# -0.41745731994039337

# %% [markdown]
# ### Correlaciones entre todos los valores

# %%
mpg_data.corr(numeric_only=True)
# Out:
#                      mpg  cilindros  desplazamiento  potencia      peso  \
# mpg             1.000000  -0.775396       -0.804203 -0.778427 -0.831741
# cilindros      -0.775396   1.000000        0.950721  0.842983  0.896017
# desplazamiento -0.804203   0.950721        1.000000  0.897257  0.932824
# potencia       -0.778427   0.842983        0.897257  1.000000  0.864538
# peso           -0.831741   0.896017        0.932824  0.864538  1.000000
# aceleracion     0.420289  -0.505419       -0.543684 -0.689196 -0.417457
# año             0.579267  -0.348746       -0.370164 -0.416361 -0.306564
# origen          0.563450  -0.562543       -0.609409 -0.455171 -0.581024
#
#                 aceleracion       año    origen
# mpg                0.420289  0.579267  0.563450
# cilindros         -0.505419 -0.348746 -0.562543
# desplazamiento    -0.543684 -0.370164 -0.609409
# potencia          -0.689196 -0.416361 -0.455171
# peso              -0.417457 -0.306564 -0.581024
# aceleracion        1.000000  0.288137  0.205873
# año                0.288137  1.000000  0.180662
# origen             0.205873  0.180662  1.000000

# %%
#año y origen no parecen correlacionables
#eliminar columnas de la correlacion
corr_data = mpg_data.drop(['año','origen'],axis=1).corr(numeric_only=True)
display(corr_data)
# Out:
#                      mpg  cilindros  desplazamiento  potencia      peso  \
# mpg             1.000000  -0.775396       -0.804203 -0.778427 -0.831741
# cilindros      -0.775396   1.000000        0.950721  0.842983  0.896017
# desplazamiento -0.804203   0.950721        1.000000  0.897257  0.932824
# potencia       -0.778427   0.842983        0.897257  1.000000  0.864538
# peso           -0.831741   0.896017        0.932824  0.864538  1.000000
# aceleracion     0.420289  -0.505419       -0.543684 -0.689196 -0.417457
#
#                 aceleracion
# mpg                0.420289
# cilindros         -0.505419
# desplazamiento    -0.543684
# potencia          -0.689196
# peso              -0.417457
# aceleracion        1.000000

# %%
# representación gráfica matplotlib
import matplotlib.pyplot as plt

# %%
# representación gráfica
corr_data.style.background_gradient(cmap=plt.get_cmap('RdYlGn'), axis=1)
# Out:
# <style type="text/css">
# #T_b9cf7_row0_col0, #T_b9cf7_row1_col1, #T_b9cf7_row2_col2, #T_b9cf7_row3_col3, #T_b9cf7_row4_col4, #T_b9cf7_row5_col5 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_b9cf7_row0_col1, #T_b9cf7_row0_col3 {
#   background-color: #b30d26;
#   color: #f1f1f1;
# }
# #T_b9cf7_row0_col2 {
#   background-color: #ab0626;
#   color: #f1f1f1;
# }
# #T_b9cf7_row0_col4, #T_b9cf7_row1_col0, #T_b9cf7_row2_col0, #T_b9cf7_row3_col0, #T_b9cf7_row4_col0, #T_b9cf7_row5_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_b9cf7_row0_col5 {
#   background-color: #afdd70;
#   color: #000000;
# }
# #T_b9cf7_row1_col2 {
#   background-color: #07753e;
#   color: #f1f1f1;
# }
# #T_b9cf7_row1_col3, #T_b9cf7_row3_col1 {
#   background-color: #16914d;
#   color: #f1f1f1;
# }
# #T_b9cf7_row1_col4, #T_b9cf7_row2_col3, #T_b9cf7_row3_col2, #T_b9cf7_row4_col1 {
#   background-color: #0e8245;
#   color: #f1f1f1;
# }
# #T_b9cf7_row1_col5 {
#   background-color: #e54e35;
#   color: #f1f1f1;
# }
# #T_b9cf7_row2_col1 {
#   background-color: #06733d;
#   color: #f1f1f1;
# }
# #T_b9cf7_row2_col4, #T_b9cf7_row4_col2 {
#   background-color: #097940;
#   color: #f1f1f1;
# }
# #T_b9cf7_row2_col5 {
#   background-color: #e34933;
#   color: #f1f1f1;
# }
# #T_b9cf7_row3_col4 {
#   background-color: #138c4a;
#   color: #f1f1f1;
# }
# #T_b9cf7_row3_col5 {
#   background-color: #bd1726;
#   color: #f1f1f1;
# }
# #T_b9cf7_row4_col3 {
#   background-color: #128a49;
#   color: #f1f1f1;
# }
# #T_b9cf7_row4_col5 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_b9cf7_row5_col0 {
#   background-color: #bbe278;
#   color: #000000;
# }
# #T_b9cf7_row5_col1 {
#   background-color: #d93429;
#   color: #f1f1f1;
# }
# #T_b9cf7_row5_col2 {
#   background-color: #d02927;
#   color: #f1f1f1;
# }
# #T_b9cf7_row5_col4 {
#   background-color: #e95538;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b9cf7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b9cf7_level0_col0" class="col_heading level0 col0" >mpg</th>
#       <th id="T_b9cf7_level0_col1" class="col_heading level0 col1" >cilindros</th>
#       <th id="T_b9cf7_level0_col2" class="col_heading level0 col2" >desplazamiento</th>
#       <th id="T_b9cf7_level0_col3" class="col_heading level0 col3" >potencia</th>
#       <th id="T_b9cf7_level0_col4" class="col_heading level0 col4" >peso</th>
#       <th id="T_b9cf7_level0_col5" class="col_heading level0 col5" >aceleracion</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9cf7_level0_row0" class="row_heading level0 row0" >mpg</th>
#       <td id="T_b9cf7_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_b9cf7_row0_col1" class="data row0 col1" >-0.775396</td>
#       <td id="T_b9cf7_row0_col2" class="data row0 col2" >-0.804203</td>
#       <td id="T_b9cf7_row0_col3" class="data row0 col3" >-0.778427</td>
#       <td id="T_b9cf7_row0_col4" class="data row0 col4" >-0.831741</td>
#       <td id="T_b9cf7_row0_col5" class="data row0 col5" >0.420289</td>
#     </tr>
#     <tr>
#       <th id="T_b9cf7_level0_row1" class="row_heading level0 row1" >cilindros</th>
#       <td id="T_b9cf7_row1_col0" class="data row1 col0" >-0.775396</td>
#       <td id="T_b9cf7_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_b9cf7_row1_col2" class="data row1 col2" >0.950721</td>
#       <td id="T_b9cf7_row1_col3" class="data row1 col3" >0.842983</td>
#       <td id="T_b9cf7_row1_col4" class="data row1 col4" >0.896017</td>
#       <td id="T_b9cf7_row1_col5" class="data row1 col5" >-0.505419</td>
#     </tr>
#     <tr>
#       <th id="T_b9cf7_level0_row2" class="row_heading level0 row2" >desplazamiento</th>
#       <td id="T_b9cf7_row2_col0" class="data row2 col0" >-0.804203</td>
#       <td id="T_b9cf7_row2_col1" class="data row2 col1" >0.950721</td>
#       <td id="T_b9cf7_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_b9cf7_row2_col3" class="data row2 col3" >0.897257</td>
#       <td id="T_b9cf7_row2_col4" class="data row2 col4" >0.932824</td>
#       <td id="T_b9cf7_row2_col5" class="data row2 col5" >-0.543684</td>
#     </tr>
#     <tr>
#       <th id="T_b9cf7_level0_row3" class="row_heading level0 row3" >potencia</th>
#       <td id="T_b9cf7_row3_col0" class="data row3 col0" >-0.778427</td>
#       <td id="T_b9cf7_row3_col1" class="data row3 col1" >0.842983</td>
#       <td id="T_b9cf7_row3_col2" class="data row3 col2" >0.897257</td>
#       <td id="T_b9cf7_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_b9cf7_row3_col4" class="data row3 col4" >0.864538</td>
#       <td id="T_b9cf7_row3_col5" class="data row3 col5" >-0.689196</td>
#     </tr>
#     <tr>
#       <th id="T_b9cf7_level0_row4" class="row_heading level0 row4" >peso</th>
#       <td id="T_b9cf7_row4_col0" class="data row4 col0" >-0.831741</td>
#       <td id="T_b9cf7_row4_col1" class="data row4 col1" >0.896017</td>
#       <td id="T_b9cf7_row4_col2" class="data row4 col2" >0.932824</td>
#       <td id="T_b9cf7_row4_col3" class="data row4 col3" >0.864538</td>
#       <td id="T_b9cf7_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_b9cf7_row4_col5" class="data row4 col5" >-0.417457</td>
#     </tr>
#     <tr>
#       <th id="T_b9cf7_level0_row5" class="row_heading level0 row5" >aceleracion</th>
#       <td id="T_b9cf7_row5_col0" class="data row5 col0" >0.420289</td>
#       <td id="T_b9cf7_row5_col1" class="data row5 col1" >-0.505419</td>
#       <td id="T_b9cf7_row5_col2" class="data row5 col2" >-0.543684</td>
#       <td id="T_b9cf7_row5_col3" class="data row5 col3" >-0.689196</td>
#       <td id="T_b9cf7_row5_col4" class="data row5 col4" >-0.417457</td>
#       <td id="T_b9cf7_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# correlación más negativa
mpg_data.drop(['año','origen'],axis=1).corr(numeric_only=True).idxmin()
# Out:
# mpg                   peso
# cilindros              mpg
# desplazamiento         mpg
# potencia               mpg
# peso                   mpg
# aceleracion       potencia
# dtype: object

# %%
# correlación más positiva
mpg_data.drop(['año','origen'],axis=1).corr(numeric_only=True).idxmax()  #consigo misma....
# Out:
# mpg                          mpg
# cilindros              cilindros
# desplazamiento    desplazamiento
# potencia                potencia
# peso                        peso
# aceleracion          aceleracion
# dtype: object

# %%
# tabla similar con las correlaciones más positivas (evitar parejas del mismo valor)
positive_corr = mpg_data.drop(['año','origen'],axis=1).corr(numeric_only=True)
np.fill_diagonal(positive_corr.values, 0)
display(positive_corr)
positive_corr.idxmax()
# Out:
#                      mpg  cilindros  desplazamiento  potencia      peso  \
# mpg             0.000000  -0.775396       -0.804203 -0.778427 -0.831741
# cilindros      -0.775396   0.000000        0.950721  0.842983  0.896017
# desplazamiento -0.804203   0.950721        0.000000  0.897257  0.932824
# potencia       -0.778427   0.842983        0.897257  0.000000  0.864538
# peso           -0.831741   0.896017        0.932824  0.864538  0.000000
# aceleracion     0.420289  -0.505419       -0.543684 -0.689196 -0.417457
#
#                 aceleracion
# mpg                0.420289
# cilindros         -0.505419
# desplazamiento    -0.543684
# potencia          -0.689196
# peso              -0.417457
# aceleracion        0.000000
# mpg                  aceleracion
# cilindros         desplazamiento
# desplazamiento         cilindros
# potencia          desplazamiento
# peso              desplazamiento
# aceleracion                  mpg
# dtype: object

# %%
positive_corr.style.background_gradient(cmap=plt.get_cmap('RdYlGn'), axis=1, vmin=-1.0, vmax=1.0)
# Out:
# <style type="text/css">
# #T_86c12_row0_col0, #T_86c12_row1_col1, #T_86c12_row2_col2, #T_86c12_row3_col3, #T_86c12_row4_col4, #T_86c12_row5_col5 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_86c12_row0_col1, #T_86c12_row0_col3, #T_86c12_row1_col0, #T_86c12_row3_col0 {
#   background-color: #da362a;
#   color: #f1f1f1;
# }
# #T_86c12_row0_col2, #T_86c12_row2_col0 {
#   background-color: #d62f27;
#   color: #f1f1f1;
# }
# #T_86c12_row0_col4, #T_86c12_row4_col0 {
#   background-color: #ce2827;
#   color: #f1f1f1;
# }
# #T_86c12_row0_col5, #T_86c12_row5_col0 {
#   background-color: #a0d669;
#   color: #000000;
# }
# #T_86c12_row1_col2, #T_86c12_row2_col1 {
#   background-color: #06733d;
#   color: #f1f1f1;
# }
# #T_86c12_row1_col3, #T_86c12_row3_col1 {
#   background-color: #148e4b;
#   color: #f1f1f1;
# }
# #T_86c12_row1_col4, #T_86c12_row2_col3, #T_86c12_row3_col2, #T_86c12_row4_col1 {
#   background-color: #0d8044;
#   color: #f1f1f1;
# }
# #T_86c12_row1_col5, #T_86c12_row5_col1 {
#   background-color: #f88c51;
#   color: #f1f1f1;
# }
# #T_86c12_row2_col4, #T_86c12_row4_col2 {
#   background-color: #08773f;
#   color: #f1f1f1;
# }
# #T_86c12_row2_col5, #T_86c12_row5_col2 {
#   background-color: #f67f4b;
#   color: #f1f1f1;
# }
# #T_86c12_row3_col4, #T_86c12_row4_col3 {
#   background-color: #118848;
#   color: #f1f1f1;
# }
# #T_86c12_row3_col5, #T_86c12_row5_col3 {
#   background-color: #e65036;
#   color: #f1f1f1;
# }
# #T_86c12_row4_col5, #T_86c12_row5_col4 {
#   background-color: #fca85e;
#   color: #000000;
# }
# </style>
# <table id="T_86c12">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_86c12_level0_col0" class="col_heading level0 col0" >mpg</th>
#       <th id="T_86c12_level0_col1" class="col_heading level0 col1" >cilindros</th>
#       <th id="T_86c12_level0_col2" class="col_heading level0 col2" >desplazamiento</th>
#       <th id="T_86c12_level0_col3" class="col_heading level0 col3" >potencia</th>
#       <th id="T_86c12_level0_col4" class="col_heading level0 col4" >peso</th>
#       <th id="T_86c12_level0_col5" class="col_heading level0 col5" >aceleracion</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_86c12_level0_row0" class="row_heading level0 row0" >mpg</th>
#       <td id="T_86c12_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_86c12_row0_col1" class="data row0 col1" >-0.775396</td>
#       <td id="T_86c12_row0_col2" class="data row0 col2" >-0.804203</td>
#       <td id="T_86c12_row0_col3" class="data row0 col3" >-0.778427</td>
#       <td id="T_86c12_row0_col4" class="data row0 col4" >-0.831741</td>
#       <td id="T_86c12_row0_col5" class="data row0 col5" >0.420289</td>
#     </tr>
#     <tr>
#       <th id="T_86c12_level0_row1" class="row_heading level0 row1" >cilindros</th>
#       <td id="T_86c12_row1_col0" class="data row1 col0" >-0.775396</td>
#       <td id="T_86c12_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_86c12_row1_col2" class="data row1 col2" >0.950721</td>
#       <td id="T_86c12_row1_col3" class="data row1 col3" >0.842983</td>
#       <td id="T_86c12_row1_col4" class="data row1 col4" >0.896017</td>
#       <td id="T_86c12_row1_col5" class="data row1 col5" >-0.505419</td>
#     </tr>
#     <tr>
#       <th id="T_86c12_level0_row2" class="row_heading level0 row2" >desplazamiento</th>
#       <td id="T_86c12_row2_col0" class="data row2 col0" >-0.804203</td>
#       <td id="T_86c12_row2_col1" class="data row2 col1" >0.950721</td>
#       <td id="T_86c12_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_86c12_row2_col3" class="data row2 col3" >0.897257</td>
#       <td id="T_86c12_row2_col4" class="data row2 col4" >0.932824</td>
#       <td id="T_86c12_row2_col5" class="data row2 col5" >-0.543684</td>
#     </tr>
#     <tr>
#       <th id="T_86c12_level0_row3" class="row_heading level0 row3" >potencia</th>
#       <td id="T_86c12_row3_col0" class="data row3 col0" >-0.778427</td>
#       <td id="T_86c12_row3_col1" class="data row3 col1" >0.842983</td>
#       <td id="T_86c12_row3_col2" class="data row3 col2" >0.897257</td>
#       <td id="T_86c12_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_86c12_row3_col4" class="data row3 col4" >0.864538</td>
#       <td id="T_86c12_row3_col5" class="data row3 col5" >-0.689196</td>
#     </tr>
#     <tr>
#       <th id="T_86c12_level0_row4" class="row_heading level0 row4" >peso</th>
#       <td id="T_86c12_row4_col0" class="data row4 col0" >-0.831741</td>
#       <td id="T_86c12_row4_col1" class="data row4 col1" >0.896017</td>
#       <td id="T_86c12_row4_col2" class="data row4 col2" >0.932824</td>
#       <td id="T_86c12_row4_col3" class="data row4 col3" >0.864538</td>
#       <td id="T_86c12_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_86c12_row4_col5" class="data row4 col5" >-0.417457</td>
#     </tr>
#     <tr>
#       <th id="T_86c12_level0_row5" class="row_heading level0 row5" >aceleracion</th>
#       <td id="T_86c12_row5_col0" class="data row5 col0" >0.420289</td>
#       <td id="T_86c12_row5_col1" class="data row5 col1" >-0.505419</td>
#       <td id="T_86c12_row5_col2" class="data row5 col2" >-0.543684</td>
#       <td id="T_86c12_row5_col3" class="data row5 col3" >-0.689196</td>
#       <td id="T_86c12_row5_col4" class="data row5 col4" >-0.417457</td>
#       <td id="T_86c12_row5_col5" class="data row5 col5" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
mpg_data
# Out:
#       mpg  cilindros  desplazamiento  potencia    peso  aceleracion  año  \
# 0    18.0          8           307.0     130.0  3504.0         12.0   70
# 1    15.0          8           350.0     165.0  3693.0         11.5   70
# 2    18.0          8           318.0     150.0  3436.0         11.0   70
# 3    16.0          8           304.0     150.0  3433.0         12.0   70
# 4    17.0          8           302.0     140.0  3449.0         10.5   70
# ..    ...        ...             ...       ...     ...          ...  ...
# 393  27.0          4           140.0      86.0  2790.0         15.6   82
# 394  44.0          4            97.0      52.0  2130.0         24.6   82
# 395  32.0          4           135.0      84.0  2295.0         11.6   82
# 396  28.0          4           120.0      79.0  2625.0         18.6   82
# 397  31.0          4           119.0      82.0  2720.0         19.4   82
#
#      origen                     nombre
# 0         1  chevrolet chevelle malibu
# 1         1          buick skylark 320
# 2         1         plymouth satellite
# 3         1              amc rebel sst
# 4         1                ford torino
# ..      ...                        ...
# 393       1            ford mustang gl
# 394       2                  vw pickup
# 395       1              dodge rampage
# 396       1                ford ranger
# 397       1                 chevy s-10
#
# [398 rows x 9 columns]

# %%
corr_data = mpg_data.loc[:,'mpg':'aceleracion']

# %% [markdown]
# ## Ejercicios

# %% [markdown]
# - Ejercicios para practicar Pandas: https://github.com/ajcr/100-pandas-puzzles/blob/master/100-pandas-puzzles.ipynb
# - Soluciones en: https://github.com/ajcr/100-pandas-puzzles/blob/master/100-pandas-puzzles-with-solutions.ipynb
